# %%
# BY USING CODE OF JUPYTER , XLSV DATASET , MYSQL DATABASE .

# Step 1: SQL Code

# If using Microsoft SQL Server:

# -- Create Database
# CREATE DATABASE bi_lab;

# -- Use Database
# USE bi_lab;
# SHOW DATABASES;

# -- Create Sales Table
# CREATE TABLE sales_data (

#     order_number INT,

#     quantity_ordered INT,

#     price_each DECIMAL(10,2),

#     sales DECIMAL(10,2),

#     order_date VARCHAR(50),

#     status VARCHAR(30),

#     product_line VARCHAR(50),

#     country VARCHAR(50)
    
#     );


# -- Verify Table
# DESC sales_data;

 
# SELECT * FROM sales_data;

# DROP TABLE sales_data;
 
# DROP DATABASE bi_lab;




# STEP 2 :::

# !pip install pandas sqlalchemy pymysql openpyxl


# ---------------------------------------------------------
# IMPORT DATA FROM EXCEL / CSV
# AND LOAD INTO MYSQL DATABASE
# ---------------------------------------------------------

import pandas as pd
from sqlalchemy import create_engine


# ---------------------------------------------------------
# Step 1 : Load Data from Excel / CSV
# ---------------------------------------------------------

# For Excel use:
# data = pd.read_excel("sales_data.xlsx")

# For CSV use:
# data = pd.read_csv("sales_data_sample.csv")

data = pd.read_csv(
    "sales_data_sample.csv",
    encoding="latin1"
)

# or:

# data = pd.read_csv(
#     "sales_data_sample.csv",
#     encoding="cp1252"
# )

print("Source Data Loaded Successfully")
print(data.head())




# for Practical code 3 
# ---------------------------------------------------------
# Step 2 : Database Connection
# ---------------------------------------------------------

engine = create_engine(
    "mysql+pymysql://root:ishwar2611%40G@localhost/bi_lab"
)

# ---------------------------------------------------------
# Step 3 : Load Data into Target System
# ---------------------------------------------------------

data.to_sql(
    name="sales_data",
    con=engine,
    if_exists="replace",
    index=False
)

print("\nData Loaded Successfully into SQL Database")
print("Target Table : sales_data")
# Out:
# ...
# Source Data Loaded Successfully
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
# Practical using Microsoft Power BI

### Problem Statement: Import data from different sources (Excel, SQL Server, Oracle, etc.) and load into target system. Perform ETL and visualize the data.**

# Dataset Used

Example: sales_data.xlsx   or   sales_data_sample.csv

Dataset contains columns such as: ORDERNUMBER
QUANTITYORDERED ,
PRICEEACH , 
SALES , 
ORDERDATE ,
STATUS , 
PRODUCTLINE ,
COUNTRY .

# Part 1: Import Sales Data from Excel / CSV

### Step 1
Open **Microsoft Power BI Desktop**

### Step 2

Click:  Home → Get Data

### Step 3
Choose:

For Excel:  Excel Workbook

For CSV:   Text/CSV


### Step 4

Select your file:

Example:  sales_data_sample.csv

### Step 5

Preview the dataset.

Verify columns like:  ORDERNUMBER
SALES
COUNTRY
PRODUCTLINE

### Step 6

Click:  Load

Now sales data is loaded into Power BI.


# Part 2: Import Sales Data from MySQL

### Step 1

Click:  Home → Get Data

### Step 2

Search:   MySQL Database

### Step 3

Enter:
Example:   Server : localhost
            Database : bi_lab


### Step 4

Enter MySQL username and password.

Example:  Username : Ishwar
Password : ABC123

### Step 5

Choose table:  sales_data

### Step 6

Click:   Load

Now MySQL sales data is loaded into Power BI.

# Part 3: Transform Sales Data (ETL)

Click:   Transform Data


Power Query Editor opens.

Perform these transformations:

✅ Remove null values
✅ Remove duplicate records
✅ Rename column names
✅ Change data types
✅ Filter unwanted rows

Example datatype changes:  ORDERDATE → Date
SALES → Decimal Number
COUNTRY → Text
QUANTITYORDERED → Whole Number
    

Then click:  Close & Apply

Now transformed data is loaded into Power BI.

# Part 4: Create Sales Dashboard

Create the following visualizations:


## 1. Table Visualization

Drag columns:  ORDERNUMBER
PRODUCTLINE
COUNTRY
SALES


Displays sales transaction details.

## 2. Bar Chart

Fields:  Axis → COUNTRY
Values → SALES

Shows country-wise sales.

## 3. Pie Chart

Fields:   Legend → PRODUCTLINE
Values → SALES

Shows product-wise sales distribution.

## 4. Line Chart

Fields:   X-Axis → ORDERDATE
Y-Axis → SALES

Shows sales trend over time.


## 5. Card Visualization

Field:  SALES

Aggregation:  Sum

Displays total sales.

# Viva Questions

### Source system?

Excel file / CSV file / MySQL

### Target system?

Microsoft Power BI data model


### What is Power Query?

Power Query is Power BI’s data transformation tool used for cleaning and transforming data.


### Why sales dataset?

Sales data helps analyze business performance, product trends, and regional sales.


# Practical Flow

Excel/CSV/MySQL → Extract → Transform → Load → Dashboard
# Out:
#   File <string>:215
#     Get Data
#             ^
# IndentationError: unindent does not match any outer indentation level
