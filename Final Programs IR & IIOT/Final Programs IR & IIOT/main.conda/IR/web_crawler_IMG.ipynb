# %%
import pandas as pd
import csv
import requests

# %%
from bs4 import BeautifulSoup

# %%
url = "https://www.amazon.in/s?k=hot+wheeles"

# %%
responce = requests.get(url)

# %%
responce

# %%
soup = BeautifulSoup(responce.content, "html.parser")

# %%
name = []
price = []
rating = []
img = []

# %%
product = soup.find_all('span', class_="a-size-base-plus a-color-base a-text-normal")
for i in product:
    name.append(i.text)

# %%
name

# %%
star = soup.find_all('i', class_="a-icon a-icon-star-small a-star-small-4")
for i in star:
    rating.append(i.text)

# %%
rating

# %%
rupees = soup.find_all('span', class_="a-offscreen")
for i in rupees:
    price.append(i.text)

# %%
price

# %%
image = soup.find_all('img')
p = 0

# %%
for i in image:
    p+=1
    img.append(i.get('src'))
    if p==20:
        break

# %%
img

# %% [markdown]
# *Download Images*

# %%
import os

# %%
os.makedirs("amazon", exist_ok=True)

# %%
for i, url in enumerate(img):
    try:
        # Send a GET request to each image URL to fetch image data
        response = requests.get(url)
        # Write the image data to a file in the 'amazon' directory
        with open(f"amazon/{i}.jpg", 'wb') as f:
            f.write(response.content)
    except Exception as e:
        print(f"Error downloading image {i} from {url}: {e}")
