# %%
# Practical 4 :: **Data Analysis and Visualization using Microsoft Excel**

# using your **sales dataset**.


# Practical 4: Data Analysis and Visualization using Microsoft Excel

### Problem Statement:

**Perform Data Analysis and Visualization using Advanced Excel.**


# Dataset Used

File: sales_data.xlsx

Dataset columns:  ORDERNUMBER
QUANTITYORDERED
PRICEEACH
SALES
ORDERDATE
STATUS
PRODUCTLINE
COUNTRY

# Part 1: Open Dataset

## Step 1
Open: **Microsoft Excel**

(Windows Search → type Excel → Open)

## Step 2

Click:
File
 ↓
Open
 ↓
Browse

## Step 3

Select your file: sales_data.xlsx

Click: Open
Dataset opens.

# Part 2: Understand Dataset

At top you’ll see columns like:
A → ORDERNUMBER
B → QUANTITYORDERED
C → PRICEEACH
D → SALES
E → ORDERDATE
F → STATUS
G → PRODUCTLINE
H → COUNTRY

# Part 3: Sorting Data
Goal: Show highest sales first.

## Step 1

Click any cell under: SALES

Example:  D2

## Step 2
Top menu:
Data
 ↓
Sort Largest to Smallest

## Output  :  Highest sales come on top.

# Part 4: Filter Data

Goal: Show only shipped orders.

## Step 1

Click anywhere in dataset.

## Step 2

Top menu:
Data
 ↓
Filter

Now dropdown arrows appear.

## Step 3

Click dropdown on:  STATUS

## Step 4

Uncheck: Select All

Then select:  Shipped

Click:   OK

## Output

Only shipped orders shown.

# Part 5: Remove Duplicates

---

## Step 1

Select whole dataset:

Shortcut:  Ctrl + A

## Step 2

Top menu:
Data
 ↓
Remove Duplicates

## Step 3

Click:  OK
          
## Output

Duplicate rows removed.

# Part 6: Conditional Formatting

Goal: Highlight high sales.

## Step 1

Select SALES column.

Example:  D:D

## Step 2

Top menu:
Home
 ↓
Conditional Formatting


## Step 3

Click:
Highlight Cells Rules
 ↓
Greater Than

## Step 4

Enter: 5000

Click:  OK

## Output

Sales greater than 5000 highlighted.

# Part 7: Pivot Table (Most Important)

This is the heart of Advanced Excel.

## Step 1

Select whole dataset:  Ctrl + A

## Step 2

Top menu:
Insert
 ↓
Pivot Table

## Step 3

Popup appears.

Keep default settings.

Click: OK

A new sheet opens.

# Country-wise Sales Analysis

## Step 1

On right side, Pivot Fields appear.


## Step 2

Drag:  COUNTRY

to: Rows


## Step 3

Drag: SALES

to: Values

## Output

Country-wise total sales.

# Product-wise Sales Analysis

Drag: PRODUCTLINE
to Rows.

Drag:  SALES

to Values.

## Output

Product-wise sales.


# Part 8: Bar Chart

## Step 1

Click Pivot Table.

---

## Step 2

Top menu:
Insert
 ↓
Column Chart

Choose first chart.

## Output

Country-wise sales chart.

---

# Part 9: Pie Chart

---

## Step 1

Click Product Pivot Table.

---

## Step 2

Top menu:

```text id="du4j3w"
Insert
 ↓
Pie Chart
```

---

## Output

Product sales distribution.

---

# Part 10: Line Chart

Goal: Sales trend.

---

## Step 1

Select:

```text id="jlwmtd"
ORDERDATE + SALES
```

---

## Step 2

Top menu:

```text id="0e6x7c"
Insert
 ↓
Line Chart
```

---

## Output

Sales trend over time.

---

# Part 11: Basic Analysis Formulas

Click any empty cell.

---

## Total Sales

Type:
=SUM(D:D)
```

Press: Enter


## Average Sales

Type:
=AVERAGE(D:D)


## Maximum Sales

Type:
=MAX(D:D)


## Minimum Sales

Type:
=MIN(D:D)


## Total Records

Type:   =COUNT(D:D)

# Final Practical Flow

Open Excel
    ↓
Open Dataset
    ↓
Sort Data
    ↓
Filter Data
    ↓
Remove Duplicates
    ↓
Conditional Formatting
    ↓
Pivot Table
    ↓
Bar Chart
    ↓
Pie Chart
    ↓
Line Chart
    ↓
Formulas
```

If you follow these clicks exactly, you can complete this practical even if you’ve never used Excel before.
